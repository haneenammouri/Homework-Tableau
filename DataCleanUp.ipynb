# %%
import pandas as pd
import numpy as np

# %%
# Extract  CSV Files

citibikes_2018_spring_file = "JC-201804-citibike-tripdata.csv"
citibikes_2018_summer_file = "JC-201808-citibike-tripdata.csv"
citibikes_2018_winter_file = "JC-201812-citibike-tripdata.csv"
citibikes_2019_spring_file = "JC-201903-citibike-tripdata.csv"

# %%
# Read each  Data File and store into Pandas DataFrame

citibikes_2018_spring_df = pd.read_csv(citibikes_2018_spring_file)
citibikes_2018_summer_df = pd.read_csv(citibikes_2018_summer_file)
citibikes_2018_winter_df = pd.read_csv(citibikes_2018_winter_file)
citibikes_2019_spring_df = pd.read_csv(citibikes_2019_spring_file)

# %%
# Combine Data File and store into Pandas DataFrame

citibikes_2018_spring_summer_df = citibikes_2018_spring_df.append(citibikes_2018_summer_df)
citibikes_2018_spring_summer_winter_df = citibikes_2018_spring_summer_df.append(citibikes_2018_winter_df)
#citibikes_2018_spring_summer_winter_df.head()
citibikes_2018_2019_spring_df = citibikes_2018_spring_df.append(citibikes_2019_spring_df)
#citibikes_2018_2019_spring_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1           298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2          1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3          1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4           559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3638       Washington St
# ...

# %%
citibikes_2018_spring_summer_winter_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1814  2018-04-01 09:43:51.1590  2018-04-01 10:14:06.1300
# 1               298  2018-04-01 11:42:53.7090  2018-04-01 11:47:51.8770
# 2              1060  2018-04-01 12:43:11.9640  2018-04-01 13:00:52.8700
# 3              1035  2018-04-01 12:43:40.5890  2018-04-01 13:00:55.6620
# 4               559  2018-04-01 12:56:47.4600  2018-04-01 13:06:06.7710
# 5               232  2018-04-01 15:29:47.3040  2018-04-01 15:33:39.3650
# 6               149  2018-04-01 15:43:48.2360  2018-04-01 15:46:17.2380
# 7              1024  2018-04-01 15:48:56.7600  2018-04-01 16:06:01.4630
# 8               882  2018-04-01 16:21:50.3390  2018-04-01 16:36:32.4390
# 9               676  2018-04-01 16:46:24.8250  2018-04-01 16:57:41.3880
# 10              605  2018-04-01 16:47:47.5510  2018-04-01 16:57:53.5100
# 11              337  2018-04-01 19:42:28.2020  2018-04-01 19:48:05.5050
# ...

# %%
cols = list(citibikes_2018_spring_summer_winter_df)
cols
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
citibikes_2018_spring_summer_winter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88271 entries, 0 to 20204
# Data columns (total 15 columns):
# tripduration               88271 non-null int64
# starttime                  88271 non-null object
# stoptime                   88271 non-null object
# start station id           88271 non-null int64
# start station name         88271 non-null object
# start station latitude     88271 non-null float64
# start station longitude    88271 non-null float64
# end station id             88271 non-null int64
# end station name           88271 non-null object
# end station latitude       88271 non-null float64
# end station longitude      88271 non-null float64
# bikeid                     88271 non-null int64
# usertype                   88271 non-null object
# birth year                 88271 non-null int64
# gender                     88271 non-null int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 10.8+ MB

# %%
citibikes_2018_spring_summer_winter_df_clean= citibikes_2018_spring_summer_winter_df.dropna(axis=0)
citibikes_2018_2019_spring_df_clean = citibikes_2018_2019_spring_df.dropna(axis=0)

# %%
citibikes_2018_spring_summer_winter_df_clean.to_csv('citibikes_2018_spring_summer_winter_df_clean.csv')
citibikes_2018_2019_spring_df_clean.to_csv("citibikes_2018_2019_spring_df_clean.csv")

# %%
def convert24(str1): 
      
    # Checking if last two elements of time 
    # is AM and first two elements are 12 
    if str1[-2:] == "AM" and str1[:2] == "12": 
        return "00" + str1[2:-2] 
          
    # remove the AM     
    elif str1[-2:] == "AM": 
        return str1[:-2] 
      
    # Checking if last two elements of time 
    # is PM and first two elements are 12    
    elif str1[-2:] == "PM" and str1[:2] == "12": 
        return str1[:-2] 
          
    else: 
          
        # add 12 to hours and remove PM 
        return str(int(str1[:2]) + 12) + str1[2:8] 
  
# Driver Code         
print(convert24("08:05:45 PM"))
# Out:
# 20:05:45

# %%
citibikes_2018_spring_summer_winter_df_clean['starttime'].apply(convert24)
# Out:
# 0        4418-04-
# 1        4418-04-
# 2        4418-04-
# 3        4418-04-
# 4        4418-04-
# 5        4418-04-
# 6        4418-04-
# 7        4418-04-
# 8        4418-04-
# 9        4418-04-
# 10       4418-04-
# 11       4418-04-
# 12       4418-04-
# 13       4418-04-
# 14       4418-04-
# 15       4418-04-
# 16       4418-04-
# 17       4418-04-
# 18       4418-04-
# 19       4418-04-
# 20       4418-04-
# 21       4418-04-
# 22       4418-04-
# 23       4418-04-
# 24       4418-04-
# 25       4418-04-
# 26       4418-04-
# 27       4418-04-
# 28       4418-04-
# 29       4418-04-
#            ...
# 20175    4418-12-
# 20176    4418-12-
# 20177    4418-12-
# 20178    4418-12-
# 20179    4418-12-
# 20180    4418-12-
# 20181    4418-12-
# 20182    4418-12-
# 20183    4418-12-
# 20184    4418-12-
# 20185    4418-12-
# 20186    4418-12-
# 20187    4418-12-
# 20188    4418-12-
# 20189    4418-12-
# 20190    4418-12-
# 20191    4418-12-
# 20192    4418-12-
# 20193    4418-12-
# ...

# %%
citibikes_2018_spring_summer_winter_df_clean.to_csv('citibikes_2018_spring_summer_winter_df_clean.csv')
citibikes_2018_2019_spring_df_clean.to_csv("citibikes_2018_2019_spring_df_clean.csv")
